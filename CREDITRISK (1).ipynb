# %%
pip install numpy pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    -------- ------------------------------- 1.8/8.3 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.3 MB 24.5 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 21.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 25.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------  7.1/7.1 MB 34.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 29.8 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
# ...

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
cd = pd.read_csv("C:\\Users\\Lenovo\\Downloads\\Google_Downloads\\Credit.csv")

# %%
cd.shape
# Out:
# (1000, 62)

# %%
cd.head()
# Out:
#    Duration  Amount  InstallmentRatePercentage  ResidenceDuration  Age  \
# 0         6    1169                          4                  4   67
# 1        48    5951                          2                  2   22
# 2        12    2096                          2                  3   49
# 3        42    7882                          2                  4   45
# 4        24    4870                          3                  4   53
#
#    NumberExistingCredits  NumberPeopleMaintenance  Telephone  ForeignWorker  \
# 0                      2                        1          0              1
# 1                      1                        1          1              1
# 2                      1                        2          1              1
# 3                      1                        2          1              1
# 4                      2                        2          1              1
#
#   Class  ...  OtherInstallmentPlans.Bank  OtherInstallmentPlans.Stores  \
# ...

# %%
cd.describe()
# Out:
#           Duration        Amount  InstallmentRatePercentage  \
# count  1000.000000   1000.000000                1000.000000
# mean     20.903000   3271.258000                   2.973000
# std      12.058814   2822.736876                   1.118715
# min       4.000000    250.000000                   1.000000
# 25%      12.000000   1365.500000                   2.000000
# 50%      18.000000   2319.500000                   3.000000
# 75%      24.000000   3972.250000                   4.000000
# max      72.000000  18424.000000                   4.000000
#
#        ResidenceDuration          Age  NumberExistingCredits  \
# count        1000.000000  1000.000000            1000.000000
# mean            2.845000    35.546000               1.407000
# std             1.103718    11.375469               0.577654
# min             1.000000    19.000000               1.000000
# 25%             2.000000    27.000000               1.000000
# ...

# %%
cd.isnull().sum()
# Out:
# Duration                                  0
# Amount                                    0
# InstallmentRatePercentage                 0
# ResidenceDuration                         0
# Age                                       0
#                                          ..
# Housing.ForFree                           0
# Job.UnemployedUnskilled                   0
# Job.UnskilledResident                     0
# Job.SkilledEmployee                       0
# Job.Management.SelfEmp.HighlyQualified    0
# Length: 62, dtype: int64

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 62 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Duration                                1000 non-null   int64
#  1   Amount                                  1000 non-null   int64
#  2   InstallmentRatePercentage               1000 non-null   int64
#  3   ResidenceDuration                       1000 non-null   int64
#  4   Age                                     1000 non-null   int64
#  5   NumberExistingCredits                   1000 non-null   int64
#  6   NumberPeopleMaintenance                 1000 non-null   int64
#  7   Telephone                               1000 non-null   int64
#  8   ForeignWorker                           1000 non-null   int64
#  9   Class                                   1000 non-null   object
# ...

# %%
cd.dtypes.items()

# %%
for colname, datatypes in cd.dtypes.items():
    if datatypes == object :
        print(colname)
# Out:
# Class

# %%
numerical = ['Duration', 'Amount', 'InstallmentRatePercentage', 'ResidenceDuration', 'Age', 'NumberExistingCredits', 'NumberPeopleMaintenance']

# %%
categorical=[]
for colname in cd.columns:
    if colname not in numerical:
        categorical.append(colname)
        print(colname)
        print(cd[colname].unique())
        print('-'*100)
# Out:
# Telephone
# [0 1]
# ----------------------------------------------------------------------------------------------------
# ForeignWorker
# [1 0]
# ----------------------------------------------------------------------------------------------------
# Class
# ['Good' 'Bad']
# ----------------------------------------------------------------------------------------------------
# CheckingAccountStatus.lt.0
# [1 0]
# ----------------------------------------------------------------------------------------------------
# CheckingAccountStatus.0.to.200
# [0 1]
# ----------------------------------------------------------------------------------------------------
# CheckingAccountStatus.gt.200
# [0 1]
# ----------------------------------------------------------------------------------------------------
# CheckingAccountStatus.none
# [0 1]
# ----------------------------------------------------------------------------------------------------
# CreditHistory.NoCredit.AllPaid
# [0 1]
# ...

# %%
#Personal.Female.Single, Purpose.Vacation  these are two columns with zero variance in their values

# %%
for colname in cd.columns:
    if colname in numerical:
        print(colname)
        print(cd[colname].unique())
        print('-'*100)
# Out:
# Duration
# [ 6 48 12 42 24 36 30 15  9 10  7 60 18 45 11 27  8 54 20 14 33 21 16  4
#  47 13 22 39 28  5 26 72 40]
# ----------------------------------------------------------------------------------------------------
# Amount
# [ 1169  5951  2096  7882  4870  9055  2835  6948  3059  5234  1295  4308
#   1567  1199  1403  1282  2424  8072 12579  3430  2134  2647  2241  1804
#   2069  1374   426   409  2415  6836  1913  4020  5866  1264  1474  4746
#   6110  2100  1225   458  2333  1158  6204  6187  6143  1393  2299  1352
#   7228  2073  5965  1262  3378  2225   783  6468  9566  1961  6229  1391
#   1537  1953 14421  3181  5190  2171  1007  1819  2394  8133   730  1164
#   5954  1977  1526  3965  4771  9436  3832  5943  1213  1568  1755  2315
#   1412 12612  2249  1108   618  1409   797  3617  1318 15945  2012  2622
#   2337  7057  1469  2323   932  1919  2445 11938  6458  6078  7721  1410
#   1449   392  6260  7855  1680  3578  7174  2132  4281  2366  1835  3868
# ...

# %%
cd['Class'].head()
# Out:
# 0    Good
# 1     Bad
# 2    Good
# 3    Good
# 4     Bad
# Name: Class, dtype: object

# %%
cd['Class'] = cd['Class'].map({'Good': 1, 'Bad': 0})

# %%
cd['Class'].head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# Name: Class, dtype: int64

# %%
corr_matrix = cd.corr()
corr_matrix
# Out:
#                                         Duration    Amount  \
# Duration                                1.000000  0.624984
# Amount                                  0.624984  1.000000
# InstallmentRatePercentage               0.074749 -0.271316
# ResidenceDuration                       0.034067  0.028926
# Age                                    -0.036136  0.032716
# ...                                          ...       ...
# Housing.ForFree                         0.189117  0.201643
# Job.UnemployedUnskilled                -0.044043 -0.027969
# Job.UnskilledResident                  -0.181203 -0.161757
# Job.SkilledEmployee                     0.055010 -0.092636
# Job.Management.SelfEmp.HighlyQualified  0.147515  0.319715
#
#                                         InstallmentRatePercentage  \
# Duration                                                 0.074749
# Amount                                                  -0.271316
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
#heatmap shows no columns have strong correlations  therefore good for  model training data set

# %%
#LOGISTIC REGRESSION
X = cd.drop('Class', axis=1)

# %%
Y=cd['Class']

# %%
pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.8 MB 6.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/8.8 MB 4.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.6/8.8 MB 4.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 3.9/8.8 MB 5.6 MB/s eta 0:00:01
#    --------------------- ------------------ 4.7/8.8 MB 5.0 MB/s eta 0:00:01
#    --------------------------- ------------ 6.0/8.8 MB 5.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.9/8.8 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.8/8.8 MB 5.8 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#    - -------------------------------------- 1.3/39.4 MB 10.5 MB/s eta 0:00:04
#    -- ------------------------------------- 2.6/39.4 MB 6.3 MB/s eta 0:00:06
# ...

# %%
X.head()
# Out:
#    Duration  Amount  InstallmentRatePercentage  ResidenceDuration  Age  \
# 0         6    1169                          4                  4   67
# 1        48    5951                          2                  2   22
# 2        12    2096                          2                  3   49
# 3        42    7882                          2                  4   45
# 4        24    4870                          3                  4   53
#
#    NumberExistingCredits  NumberPeopleMaintenance  Telephone  ForeignWorker  \
# 0                      2                        1          0              1
# 1                      1                        1          1              1
# 2                      1                        2          1              1
# 3                      1                        2          1              1
# 4                      2                        2          1              1
#
#    CheckingAccountStatus.lt.0  ...  OtherInstallmentPlans.Bank  \
# ...

# %%
Y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# Name: Class, dtype: int64

# %%
import sklearn

# %%
from sklearn.linear_model import LogisticRegression

# %%
lrmodel_1 = LogisticRegression(max_iter=int(1e8))
lrmodel_1.fit(X, Y)
# Out:
# LogisticRegression(max_iter=100000000)

# %%
lr_preds_probs_1 = lrmodel_1.predict_proba(X)

# %%
lr_preds_probs_1
# Out:
# array([0.96233874, 0.37467613, 0.97156411, 0.7103771 , 0.2564274 ,
#        0.74660132, 0.93024439, 0.69353989, 0.98554273, 0.29044094,
#        0.3073042 , 0.1224413 , 0.80667239, 0.60179356, 0.30766275,
#        0.50764122, 0.97049458, 0.22095007, 0.41491807, 0.9201137 ,
#        0.89179405, 0.78277232, 0.86010605, 0.94910307, 0.9909045 ,
#        0.81310664, 0.85302269, 0.82228151, 0.90829638, 0.26644321,
#        0.79015961, 0.44773353, 0.57222311, 0.96498519, 0.58675392,
#        0.45935223, 0.69972608, 0.64511959, 0.90010836, 0.75792981,
#        0.8159293 , 0.74631969, 0.70311918, 0.83595931, 0.33362884,
#        0.79417869, 0.878712  , 0.89252118, 0.89941971, 0.84683078,
#        0.65314085, 0.87417605, 0.91610185, 0.98506643, 0.2738711 ,
#        0.95533584, 0.86697526, 0.65774409, 0.54343976, 0.1204358 ,
#        0.69662543, 0.98071702, 0.4974119 , 0.17183451, 0.74566068,
#        0.76978183, 0.80305809, 0.70456628, 0.52925652, 0.83904469,
# ...

# %%
lr_preds_probs_1 =lrmodel_1.predict_proba(X)[:,1]
cd['Predicted_Probs'] = lr_preds_probs_1

# %%
cd.head()
# Out:
#    Duration  Amount  InstallmentRatePercentage  ResidenceDuration  Age  \
# 0         6    1169                          4                  4   67
# 1        48    5951                          2                  2   22
# 2        12    2096                          2                  3   49
# 3        42    7882                          2                  4   45
# 4        24    4870                          3                  4   53
#
#    NumberExistingCredits  NumberPeopleMaintenance  Telephone  ForeignWorker  \
# 0                      2                        1          0              1
# 1                      1                        1          1              1
# 2                      1                        2          1              1
# 3                      1                        2          1              1
# 4                      2                        2          1              1
#
#    Class  ...  OtherInstallmentPlans.Stores  OtherInstallmentPlans.None  \
# ...

# %%
from sklearn.metrics import confusion_matrix

# %%
threshold_1 = 0.2
cd['Predictions_0.2'] = np.where(cd['Predicted_Probs'] > threshold_1, 1, 0)
cm_1 = confusion_matrix(y_pred=cd['Predictions_0.2'], y_true=cd['Class'])
print(cm_1)
# Out:
# [[ 40 260]
#  [  4 696]]

# %%
TN, FP, FN, TP = cm_1.ravel()
TPR = TP / (TP + FN)
FPR = FP / (FP + TN)
Acc = (TP + TN)/ (TP + TN + FP + FN) 

print(f"True Positive Rate for a threshold of {threshold_1} is: {TPR}")
print(f"False Positive Rate for a threshold of {threshold_1} is: {FPR}")
print(f"Accuracy score is: {Acc}")
# Out:
# True Positive Rate for a threshold of 0.2 is: 0.9942857142857143
# False Positive Rate for a threshold of 0.2 is: 0.8666666666666667
# Accuracy score is: 0.736

# %%
threshold_2 = 0.35
cd['Predictions_0.35'] = np.where(cd['Predicted_Probs'] > threshold_2, 1, 0)
cm_2 = confusion_matrix(y_pred=cd['Predictions_0.35'], y_true=cd['Class']) 
print(cm_2)
# Out:
# [[ 95 205]
#  [ 23 677]]

# %%
TN, FP, FN, TP = cm_2.ravel()

# Calculate TPR and FPR
TPR = TP / (TP + FN)
FPR = FP / (FP + TN)
Acc = (TP + TN)/ (TP + TN + FP + FN) 

print(f"True Positive Rate for a threshold of {threshold_2} is: {TPR}")
print(f"False Positive Rate for a threshold of {threshold_2} is: {FPR}")
print(f"Accuracy score is: {Acc}")
# Out:
# True Positive Rate for a threshold of 0.35 is: 0.9671428571428572
# False Positive Rate for a threshold of 0.35 is: 0.6833333333333333
# Accuracy score is: 0.772

# %%
threshold_3 = 0.5
cd['Predictions_0.5'] = np.where(cd['Predicted_Probs'] > threshold_3, 1, 0)
cm_3 = confusion_matrix(y_pred=cd['Predictions_0.5'], y_true=cd['Class']) 
print(cm_3)
# Out:
# [[157 143]
#  [ 71 629]]

# %%
TN, FP, FN, TP = cm_3.ravel()

# Calculate TPR and FPR
TPR = TP / (TP + FN)
FPR = FP / (FP + TN) 
Acc = (TP + TN)/ (TP + TN + FP + FN)

print(f"True Positive Rate for a threshold of {threshold_3} is: {TPR}")
print(f"False Positive Rate for a threshold of {threshold_3} is: {FPR}")
print(f"Accuracy score is: {Acc}")
# Out:
# True Positive Rate for a threshold of 0.5 is: 0.8985714285714286
# False Positive Rate for a threshold of 0.5 is: 0.4766666666666667
# Accuracy score is: 0.786

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
#SVM ONLY STARTS FROM HERE

# %%
 #SVM Classifier with a Radial Basis Function (RBF) as the Kernel 


import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
credit_data = pd.read_csv("C:\\Users\\Lenovo\\Downloads\\Google_Downloads\\Credit.csv")
print(credit_data.shape)

#   Binary Encoding the Class variable
credit_data['Class'] = credit_data['Class'].apply(lambda x: 0 if x == 'Bad' else 1)
print(f"No. of transactions classified as good (marked as 1): {np.sum(credit_data['Class'])}")     


#   Just re-arranging our columns
cols = [col for col in credit_data.columns if col != 'Class']
cols.append('Class')
credit_data = credit_data[cols]
# Out:
# (1000, 62)
# No. of transactions classified as good (marked as 1): 700

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(credit_data.drop("Class", axis=1),
                                                    credit_data['Class'],
                                                    test_size=0.3,
                                                    random_state=42)

# %%
numerical_variables = ['Duration', 'Amount', 'InstallmentRatePercentage', 'ResidenceDuration', 'Age', 'NumberExistingCredits', 'NumberPeopleMaintenance']

from sklearn.preprocessing import StandardScaler
scaler_2 = StandardScaler()
X_train[numerical_variables] = scaler_2.fit_transform(X_train[numerical_variables])

# %%
X_test[numerical_variables] = scaler_2.transform(X_test[numerical_variables])

# %%
X_train.head()
# Out:
#      Duration    Amount  InstallmentRatePercentage  ResidenceDuration  \
# 541  0.231016 -0.462936                   0.911164           1.057385
# 440 -0.778104 -0.512772                   0.911164           1.057385
# 482  0.735576  0.072458                   0.911164           1.057385
# 422 -0.778104 -0.824580                  -0.877938           0.150315
# 778  1.240136  0.775879                   0.911164          -0.756756
#
#           Age  NumberExistingCredits  NumberPeopleMaintenance  Telephone  \
# 541  2.179382               0.997799                -0.398673          0
# 440  0.311885              -0.722544                -0.398673          0
# 482  1.912597               0.997799                -0.398673          0
# 422  1.023312               0.997799                 2.508319          1
# 778  0.222956               0.997799                -0.398673          0
#
#      ForeignWorker  CheckingAccountStatus.lt.0  ...  \
# ...

# %%
X_test.head()
# Out:
#      Duration    Amount  InstallmentRatePercentage  ResidenceDuration  \
# 521 -0.273544 -0.073007                  -0.877938          -0.756756
# 737 -0.273544  0.327696                   0.016613           1.057385
# 740  0.231016 -0.364275                  -0.877938           0.150315
# 660 -0.778104 -0.710430                   0.016613           1.057385
# 411  0.987856  1.295110                   0.016613          -0.756756
#
#           Age  NumberExistingCredits  NumberPeopleMaintenance  Telephone  \
# 521 -1.022042              -0.722544                -0.398673          1
# 737 -0.043829              -0.722544                 2.508319          0
# 740 -0.310614              -0.722544                -0.398673          1
# 660 -1.110970              -0.722544                -0.398673          1
# 411 -0.043829               0.997799                -0.398673          0
#
#      ForeignWorker  CheckingAccountStatus.lt.0  ...  \
# ...

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# =====================================================
# 1. IMPORTS
# =====================================================
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, 
    f1_score, roc_auc_score, confusion_matrix
)

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier

# =====================================================
# 2. DATA PREPARATION
# =====================================================

X = cd.drop('Class', axis=1)
y = cd['Class']   # encoded as 0/1 (bad/good)

# Stratified split because data is imbalanced
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Scaling for LR, KNN, SVM
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# =====================================================
# 3. LOGISTIC REGRESSION WITH MULTIPLE THRESHOLDS
# =====================================================

lr = LogisticRegression(max_iter=500)
lr.fit(X_train_scaled, y_train)

# predict probabilities
lr_probs = lr.predict_proba(X_test_scaled)[:,1]

thresholds = [0.2, 0.35, 0.5]
print("\n===== LOGISTIC REGRESSION RESULTS =====")

for t in thresholds:
    preds = (lr_probs >= t).astype(int)
    print(f"\n--- Threshold: {t} ---")
    print("Accuracy :", accuracy_score(y_test, preds))
    print("Precision:", precision_score(y_test, preds))
    print("Recall   :", recall_score(y_test, preds))
    print("F1 Score :", f1_score(y_test, preds))
    print("AUC      :", roc_auc_score(y_test, lr_probs))

best_lr_auc = roc_auc_score(y_test, lr_probs)

# =====================================================
# 4. SVM CLASSIFIER
# =====================================================

svm = SVC(kernel='rbf', probability=True)
svm.fit(X_train_scaled, y_train)

svm_preds = svm.predict(X_test_scaled)
svm_probs = svm.predict_proba(X_test_scaled)[:,1]

print("\n===== SVM RESULTS =====")
print("Accuracy :", accuracy_score(y_test, svm_preds))
print("Precision:", precision_score(y_test, svm_preds))
print("Recall   :", recall_score(y_test, svm_preds))
print("AUC      :", roc_auc_score(y_test, svm_probs))

# =====================================================
# 5. KNN CLASSIFIER
# =====================================================
# =====================================================
# FINDING BEST KNN USING FNR AS MAIN METRIC
# =====================================================

k_values = [1, 3, 5, 7, 10]
knn_results = []

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_scaled, y_train)

    preds = knn.predict(X_test_scaled)
    probs = knn.predict_proba(X_test_scaled)[:, 1]

    # Confusion Matrix
    tn, fp, fn, tp = confusion_matrix(y_test, preds).ravel()

    fnr = fn / (fn + tp)      # FALSE NEGATIVE RATE
    acc = accuracy_score(y_test, preds)
    prec = precision_score(y_test, preds)
    rec = recall_score(y_test, preds)
    auc = roc_auc_score(y_test, probs)

    knn_results.append([k, fnr, acc, prec, rec, auc])

# Convert to DataFrame
knn_df = pd.DataFrame(knn_results, columns=[
    "K", "FNR", "Accuracy", "Precision", "Recall", "AUC"
])

print("\n===== KNN PERFORMANCE FOR ALL K VALUES (WITH FNR) =====")
print(knn_df)

# Best model = lowest FNR
best_knn = knn_df.loc[knn_df["FNR"].idxmin()]

print("\n===== BEST KNN BASED ON LOWEST FNR =====")
print(best_knn)


# 6. DECISION TREE
# =====================================================

dt = DecisionTreeClassifier(max_depth=5, random_state=42)
dt.fit(X_train, y_train)

dt_preds = dt.predict(X_test)
dt_probs = dt.predict_proba(X_test)[:,1]

print("\n===== DECISION TREE RESULTS =====")
print("Accuracy :", accuracy_score(y_test, dt_preds))
print("Precision:", precision_score(y_test, dt_preds))
print("Recall   :", recall_score(y_test, dt_preds))
print("AUC      :", roc_auc_score(y_test, dt_probs))

# =====================================================
# 7. BAGGING CLASSIFIER
# =====================================================

bag = BaggingClassifier(n_estimators=50, random_state=42)
bag.fit(X_train, y_train)

bag_preds = bag.predict(X_test)
bag_probs = bag.predict_proba(X_test)[:,1]

print("\n===== BAGGING CLASSIFIER RESULTS =====")
print("Accuracy :", accuracy_score(y_test, bag_preds))
print("Precision:", precision_score(y_test, bag_preds))
print("Recall   :", recall_score(y_test, bag_preds))
print("AUC      :", roc_auc_score(y_test, bag_probs))

# =====================================================
# 8. RANDOM FOREST
# =====================================================

rf = RandomForestClassifier(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)

rf_preds = rf.predict(X_test)
rf_probs = rf.predict_proba(X_test)[:,1]

print("\n===== RANDOM FOREST RESULTS =====")
print("Accuracy :", accuracy_score(y_test, rf_preds))
print("Precision:", precision_score(y_test, rf_preds))
print("Recall   :", recall_score(y_test, rf_preds))
print("AUC      :", roc_auc_score(y_test, rf_probs))

# =====================================================
# 9. SUMMARY TABLE
# =====================================================

# =====================================================
# UPDATED SUMMARY TABLE WITH FNR AND BEST KNN
# =====================================================

# Logistic Regression FNR calculation
best_lr_thresh = min([(t, fn / (fn + tp)) 
                      for t in thresholds 
                      for tn, fp, fn, tp in [confusion_matrix(y_test, (lr_probs >= t).astype(int)).ravel()] ],
                     key=lambda x: x[1])

best_lr_fnr = best_lr_thresh[1]

# Compute FNRs for other models
def get_fnr(preds):
    tn, fp, fn, tp = confusion_matrix(y_test, preds).ravel()
    return fn / (fn + tp)

results = {
    "Model": ["Logistic Regression", "SVM", "Best KNN", "Decision Tree", "Bagging", "Random Forest"],

    "Accuracy": [
        max([accuracy_score(y_test, (lr_probs >= t).astype(int)) for t in thresholds]),
        accuracy_score(y_test, svm_preds),
        best_knn["Accuracy"],
        accuracy_score(y_test, dt_preds),
        accuracy_score(y_test, bag_preds),
        accuracy_score(y_test, rf_preds)
    ],

    "Precision": [
        precision_score(y_test, (lr_probs >= 0.35).astype(int)),
        precision_score(y_test, svm_preds),
        best_knn["Precision"],
        precision_score(y_test, dt_preds),
        precision_score(y_test, bag_preds),
        precision_score(y_test, rf_preds)
    ],

    "Recall": [
        max([recall_score(y_test, (lr_probs >= t).astype(int)) for t in thresholds]),
        recall_score(y_test, svm_preds),
        best_knn["Recall"],
        recall_score(y_test, dt_preds),
        recall_score(y_test, bag_preds),
        recall_score(y_test, rf_preds)
    ],

    "FNR": [
        best_lr_fnr,
        get_fnr(svm_preds),
        best_knn["FNR"],
        get_fnr(dt_preds),
        get_fnr(bag_preds),
        get_fnr(rf_preds)
    ],

    "AUC Score": [
        best_lr_auc,
        roc_auc_score(y_test, svm_probs),
        best_knn["AUC"],
        roc_auc_score(y_test, dt_probs),
        roc_auc_score(y_test, bag_probs),
        roc_auc_score(y_test, rf_probs)
    ]
}

summary_df = pd.DataFrame(results)
print("\n===== MODEL PERFORMANCE SUMMARY (WITH FNR) =====")
print(summary_df)
# Out:
# ===== LOGISTIC REGRESSION RESULTS =====
#
# --- Threshold: 0.2 ---
# Accuracy : 0.7266666666666667
# Precision: 0.7269503546099291
# Recall   : 0.9761904761904762
# F1 Score : 0.8333333333333334
# AUC      : 0.776984126984127
#
# --- Threshold: 0.35 ---
# Accuracy : 0.7566666666666667
# Precision: 0.7751004016064257
# Recall   : 0.919047619047619
# F1 Score : 0.840958605664488
# AUC      : 0.776984126984127
#
# --- Threshold: 0.5 ---
# Accuracy : 0.7366666666666667
# Precision: 0.7937219730941704
# Recall   : 0.8428571428571429
# F1 Score : 0.8175519630484989
# AUC      : 0.776984126984127
#
# ===== SVM RESULTS =====
# Accuracy : 0.76
# Precision: 0.76953125
# Recall   : 0.9380952380952381
# AUC      : 0.7819047619047619
#
# ===== KNN PERFORMANCE FOR ALL K VALUES (WITH FNR) =====
#     K       FNR  Accuracy  Precision    Recall       AUC
# 0   1  0.238095  0.660000   0.754717  0.761905  0.592063
# 1   3  0.147619  0.703333   0.755274  0.852381  0.661931
# ...
